# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Задание (на листочке)
# Решите уравнение
# sin(x)/x=0.
#
# sin(x)/x = 0  |x
# sin(x) = 0x
# sin(x) = 0
# n * pi, где n - целое число

# %%
plt.axis([-10, 10, -1.5, 1.5])
plt.gca().set_aspect('equal')
plt.rcParams["figure.figsize"] = (15,5)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.grid(True)

x = np.linspace(-10,10,100)
y = np.sin(x)
y1 = np.sin(x)/x

plt.plot(x,y)
plt.plot(x,y1)

from sympy import *
x = Symbol('x')
print(solveset(sin(x)/x, x, domain=S.Reals))
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi), Integers) \ {0}, ImageSet(Lambda(_n, 2*_n*pi + pi), Integers) \ {0})

# %% [markdown]
# 2. Задание (на листочке)
# Даны три прямые y=k1*x+b1, y=k2*x+b2,, y=k3*x+b3. Как узнать, пересекаются они в одной точке или нет?
#
# необходимо найти точку, принадлежащую всем трем прямым.
# это можно сделать решив систему уравнений для 3 прямых - графически, постановкой или через матрицы
#
# (как это сделать без цифр,в общем виде я не понимаю)

# %% [markdown]
# 3. Задание (в программе или на листочке)
# На листе тетради «в линейку» (расстояние между линиями равно а) лежит игла (длиной b). Координаты нижней точки иглы (х,у), игла лежит под углом alfa. Пересекает ли игла линию или нет?
#
# если это тетрадка в "линейку" то есть линии параллельны то иголка пересечет какую-нибудь линию, если
#
# y0 - b * sin(alfa) >=a
#
# где y0 остаток от деления y/a

# %% [markdown]
# 4. Задание** (задание делать по желанию)
# Решите аналитически и потом численно (в программе) уравнение, зависящее от параметра а:
# sin(а*x)=0
# при условии: 0.01<a<0.02, 100<х<500.
# Т.е. надо найти решение х как функцию параметра а - построить график x=x(а).
# Если численным методом не получается найти все ветви решения x(а), то отыщите хотя бы одну.
#
# sin(a*x)=0
# a*x=accsin(0)
# a*x=0
#
# Функция синуса принимает положительные значения в первом и втором квадрантах. Для определения второго решения вычитаем решение из pi, чтобы найти решение во втором квадранте:
#
# a*x=pi-0
#
# x = pi/a
#
# на отрезке от 1 до 10 (a * x для значений 0.01<a<0.02 и 100<х<500)
# "влазиет" 3 раза  пи: пи, 2пи и 3 пи (3.14 , 6.28 и 9.42)

# %%
# plt.axis([-5, 15, -1.5, 1.5])
# plt.gca().set_aspect('equal')
# plt.rcParams["figure.figsize"] = (15,5)
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.grid(True)

a = np.linspace(0.01,0.02, 100)
x = np.linspace(100, 500,100)

t = a*x
y = np.sin(t)
y1 = np.sin(a*x)

plt.plot(t,y, color="red")
# plt.plot(x,y1, color="green")


x = Symbol('x')
print(solveset(sin(x), x, domain=S.Reals))
# Out:
# Union(ImageSet(Lambda(_n, 2*_n*pi), Integers), ImageSet(Lambda(_n, 2*_n*pi + pi), Integers))

# %%
from mpl_toolkits import mplot3d

# %%
ax = plt.axes(projection='3d')
ax.view_init(45, 50)
a = np.linspace(0.01,0.02, 100)
x = np.linspace(100, 500,100)
a,x = np.meshgrid(a,x)
y = np.sin(a*x)

ax.plot_wireframe(a, x, y)
