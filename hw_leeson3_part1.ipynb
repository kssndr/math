# %%
# %matplotlib inline
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import math

# %%
# Задание 1
vector = []
a = input("input vector = ")
vector = [int(s) for s in a.split(",")]
len_vector = 0
for i in vector:
    len_vector = len_vector + i**2
len_vector = len_vector**0.5
print(f"the length of the vector{vector} is  {len_vector:.3f}")
# Out:
# input vector = 1,1,1
# the length of the vector[1, 1, 1] is  1.732

# %%
# Задание 2
plt.axis([-5, 5, -5, 5])
plt.grid()
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.axis()
plt.gca().set_aspect('equal')

mpl.rcParams['figure.figsize'] = (8.0, 8.0)

x = np.linspace(5,-5,21)
y = 3*x + 1
y2= (-1/3)*x + 1
plt.plot(x,y,label="3*x + 1")
plt.plot(x,y2, label="(1/3)*x + 1")
plt.xlabel("x")
plt.ylabel("y")

plt.legend(loc = "best")


# общее уравнение прямой Ax+By+C=0

# %%
# Задание 3
# окружность, эллипс,гипербола.
plt.grid()
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.axis()
plt.gca().set_aspect('equal')
# plt.axis([-6, 6, -6, 6])

x_ =np.linspace(-5,5,10000)

a=2
x0=0
y0=0
y_c = (a**2 - (x_-x0)**2)**0.5 - y0
y_c2 = -(a**2 - (x_-x0)**2)**0.5 - y0
plt.plot(x_,y_c,"b", label="circle")
plt.plot(x_,y_c2,"b")

b=1
y_e = ((1-(x_**2/a**2))*b**2)**0.5
plt.plot(x_,y_e,"r", label="ellipse")
plt.plot(x_,-y_e,"r")

y_h = (-(1-(x_**2/a**2))*b**2)**0.5
plt.plot(x_,y_h, "g",label="hyperbola")
plt.plot(x_,-y_h, "g")

plt.legend(loc = "best")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in sqrt
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in sqrt
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in sqrt
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.grid()
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.gca().set_aspect('equal')

a=2
 
xx=[]
yy=[]
yy2=[]
i=-a
while i<a:
    xx.append(i)
    yy.append(math.sqrt(a**2 - i**2))
    yy2.append(-math.sqrt(a**2 - i**2))
    i=i+0.005
plt.plot(xx,yy)
plt.plot(xx,yy2)

# %%
plt.grid()
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.gca().set_aspect('equal')

a=3
b=1
xx=[]
yy=[]
yy2=[]
i=-a
while i<a:
    xx.append(i)
    yy.append(math.sqrt((1-(i**2/a**2))*b**2))
    yy2.append(-math.sqrt((1-(i**2/a**2))*b**2))
    i=i+0.005
plt.plot(xx,yy)
plt.plot(xx,yy2)

# %%
plt.grid()
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.gca().set_aspect('equal')

a=3
b=2
xx=[]
yy=[]
yy2=[]
i=-a-b
while i<a+b:
    xx.append(i)
    yy.append((((i**2/a**2)-1)*b**2)**0.5)
    yy2.append(-(((i**2/a**2)-1)*b**2)**0.5)
    i=i+0.01
plt.plot(xx,yy)
plt.plot(xx,yy2)
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.grid()
plt.axvline(0, color='gray')
plt.axhline(0, color='gray')
plt.gca().set_aspect('equal')


x = np.linspace(-5,5,10000)
plt.axis([-5, 5, -5, 5])
y = 1/x
plt.plot(x,y,"b:")

# asimptoty
a =1
b =2
y_a= b/a*x
y_a2=-b/a*x
plt.plot(x,y_a,"g--")
plt.plot(x,y_a2,"g--")

# top
plt.plot(a,0,"ro")
plt.plot(-a,0,"ro")

# hyperbola
yh=(((x-0)**2/a**2 - 1)*b**2)**0.5-0
yh2=-(((x-0)**2/a**2 - 1)*b**2)**0.5-0
plt.plot(x,yh,"r")
plt.plot(x,yh2,"r")

# focus
c=math.sqrt(a**2+b**2)
plt.plot(c,0,"bo")
plt.plot(-c,0,"bo")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in sqrt
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in sqrt

# %%
from mpl_toolkits import mplot3d

# %%
# ax = plt.axes(projection='3d')
fig, ax = plt.subplots(1, 2, figsize=(20, 15), subplot_kw=dict(projection='3d'))
ax[0].view_init(15, 10)
ax[0].set_xlabel('X Label')
ax[0].set_ylabel('Y Label')
ax[0].set_zlabel('Z Label')
ax[0].axes.set_aspect('equal')

ax[1].view_init(0, 0)
ax[1].set_xlabel('X Label')
ax[1].set_ylabel('Y Label')
ax[1].set_zlabel('Z Label')
ax[1].axes.set_aspect('equal')

# Data for a three-dimensional line
# zline = np.linspace(-10,10,10)
# xline = zline
# yline = zline
# ax[0].plot3D(xline, yline, zline, 'blue')
# ax[1].plot3D(xline, yline, zline, 'blue')

# line in 3d
# point in 3d
m=[1,-3,2]
# vector in 3d
v=[3,-0.5,1] 
t=np.linspace(-5,5,10)
xline1 = v[0]*t+m[0]
yline1 = v[1]*t+m[1]
zline1 = v[2]*t+m[2]
ax[0].plot3D(xline1, yline1, zline1, 'green')
ax[0].quiver(m[0], m[1], m[2],v[0],v[1],v[2],arrow_length_ratio=0.5,color ="brown")
ax[1].plot3D(xline1, yline1, zline1, 'green')
ax[1].quiver(m[0], m[1], m[2],v[0],v[1],v[2],arrow_length_ratio=0.5,color ="brown")

# point(0,0,0)
xdot=[0]
ydot=[0]
zdot=[0]
ax[0].scatter3D(xdot, ydot, zdot, color ='red')
ax[1].scatter3D(xdot, ydot, zdot, color ='red')

xdot1=m[0]
ydot1=m[1]
zdot1=m[2]
ax[0].scatter3D(xdot1, ydot1, zdot1, color ='green')
ax[1].scatter3D(xdot1, ydot1, zdot1, color ='green')


# surface
# vector normal
n=[0,2,1]
# point
p=[0,3,3]
p1=[0,0,0]
X=t
Y=t
X,Y = np.meshgrid(X,Y)
Z=((-n[0]*X+n[0]*p[0]-n[1]*Y+n[1]*p[1])/n[2])+p[2]
Z1=((-n[0]*X+n[0]*p1[0]-n[1]*Y+n[1]*p1[1])/n[2])+p1[2]
# ax[0].plot_surface(X, Y, Z,rstride=2, cstride=2,color='yellow')
ax[0].quiver(p[0], p[1], p[2],n[0],n[1],n[2],arrow_length_ratio=0.5,color ="green")
ax[0].plot_wireframe(X, Y, Z, rstride=1, cstride=1, color="yellow")
ax[1].plot_wireframe(X, Y, Z, rstride=1, cstride=1, color="yellow")
ax[1].scatter3D(p[0], p[1], p[2], color ='black');
ax[1].quiver(p[0], p[1], p[2],n[0],n[1],n[2],arrow_length_ratio=0.5,color ="green")

ax[0].quiver(p1[0], p1[1], p1[2],n[0],n[1],n[2],arrow_length_ratio=0.5,color ="blue")
ax[1].quiver(p1[0], p1[1], p1[2],n[0],n[1],n[2],arrow_length_ratio=0.5,color ="blue")
ax[0].plot_wireframe(X, Y, Z1, rstride=1, cstride=1, color="orange")
ax[1].plot_wireframe(X, Y, Z1, rstride=1, cstride=1, color="orange")

# %%
# задание 5

fig, ax = plt.subplots(1, 2, figsize=(20, 15), subplot_kw=dict(projection='3d'))

ax[0].view_init(15, 80)
ax[0].set_xlabel('X Label')
ax[0].set_ylabel('Y Label')
ax[0].set_zlabel('Z Label')
ax[0].axes.set_aspect('equal', adjustable='box')

ax[1].view_init(15, 80)
ax[1].set_xlabel('X Label')
ax[1].set_ylabel('Y Label')
ax[1].set_zlabel('Z Label')
ax[1].axes.set_aspect('equal', adjustable='box')


aa=1
bb=2
cc=1
tt=np.linspace(-5,5,500)
xx=tt
yy=tt
xx,yy=np.meshgrid(xx,yy)
zz=np.sqrt((xx**2/aa**2+yy**2/bb**2-1)/c**2)

zz2=np.sqrt(bb**2-xx**2-yy**2)

ax[0].plot_wireframe(xx, yy, zz, rstride=10, cstride=10,color='gray')
ax[0].plot_surface(xx, yy, -zz,rstride=10, cstride=10,color='gray')

ax[1].plot_wireframe(xx, yy, zz2, rstride=10, cstride=10,color='gray')
ax[1].plot_surface(xx, yy, -zz2,rstride=10, cstride=10,color='gray')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: RuntimeWarning: invalid value encountered in sqrt
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:27: RuntimeWarning: invalid value encountered in sqrt
